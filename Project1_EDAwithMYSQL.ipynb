# %%
# !pip install SQLAlchemy
from sqlalchemy import create_engine
import mysql.connector
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
engine=create_engine('mysql+mysqlconnector://root:'+'love.2009'+"@localhost/project1")

# %%
df=pd.read_sql_table('studmarks',engine)
df
# Out:
#        Name Gender        DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      Annu      F 1988-04-05     45       87         52       89       55
# 1     Farha      F 1990-08-12     55       63         89       75       78
# 2  Jennifer      F 1989-09-02     58       96         78       46       96
# 3   Jessica      F 1990-08-12     78       96         86       63       54
# 4      John      M 1988-04-05     55       45         56       87       21
# 5    Mukesh      M 1989-09-02     96       46         77       83       58
# 6     pooja      F 1987-05-04     55       64         61       58       75
# 7    Ramesh      M 1989-05-25     25       54         89       76       95
# 8    Ritesh      M 1989-05-25     54       76         87       56       25
# 9    Suresh      M 1987-05-04     75       96         78       64       90
#
#    Economics  History  Civis
# 0         89       87     52
# 1         75       63     89
# 2         77       83     53
# ...

# %%
df.shape
# Out:
# (10, 11)

# %%
df.dtypes
# Out:
# Name                 object
# Gender               object
# DOB          datetime64[ns]
# Maths                 int64
# Physics               int64
# Chemistry             int64
# English               int64
# Biology               int64
# Economics             int64
# History               int64
# Civis                 int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'DOB', 'Maths', 'Physics', 'Chemistry', 'English',
#        'Biology', 'Economics', 'History', 'Civis'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       10 non-null     object
#  1   Gender     10 non-null     object
#  2   DOB        10 non-null     datetime64[ns]
#  3   Maths      10 non-null     int64
#  4   Physics    10 non-null     int64
#  5   Chemistry  10 non-null     int64
#  6   English    10 non-null     int64
#  7   Biology    10 non-null     int64
#  8   Economics  10 non-null     int64
#  9   History    10 non-null     int64
#  10  Civis      10 non-null     int64
# dtypes: datetime64[ns](1), int64(8), object(2)
# memory usage: 1008.0+ bytes

# %%
df.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History    Civis
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
#checking for any missing data
sns.heatmap(df.isnull())

# %%
df.isnull()
# Out:
#     Name  Gender    DOB  Maths  Physics  Chemistry  English  Biology  \
# 0  False   False  False  False    False      False    False    False
# 1  False   False  False  False    False      False    False    False
# 2  False   False  False  False    False      False    False    False
# 3  False   False  False  False    False      False    False    False
# 4  False   False  False  False    False      False    False    False
# 5  False   False  False  False    False      False    False    False
# 6  False   False  False  False    False      False    False    False
# 7  False   False  False  False    False      False    False    False
# 8  False   False  False  False    False      False    False    False
# 9  False   False  False  False    False      False    False    False
#
#    Economics  History  Civis
# 0      False    False  False
# 1      False    False  False
# 2      False    False  False
# 3      False    False  False
# 4      False    False  False
# ...

# %%
df.isnull().sum()
# Out:
# Name         0
# Gender       0
# DOB          0
# Maths        0
# Physics      0
# Chemistry    0
# English      0
# Biology      0
# Economics    0
# History      0
# Civis        0
# dtype: int64

# %% [raw]
# There are no missing values

# %%
df['Total']=df.sum(axis=1)
df
# Out:
#        Name Gender        DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      Annu      F 1988-04-05     45       87         52       89       55
# 1     Farha      F 1990-08-12     55       63         89       75       78
# 2  Jennifer      F 1989-09-02     58       96         78       46       96
# 3   Jessica      F 1990-08-12     78       96         86       63       54
# 4      John      M 1988-04-05     55       45         56       87       21
# 5    Mukesh      M 1989-09-02     96       46         77       83       58
# 6     pooja      F 1987-05-04     55       64         61       58       75
# 7    Ramesh      M 1989-05-25     25       54         89       76       95
# 8    Ritesh      M 1989-05-25     54       76         87       56       25
# 9    Suresh      M 1987-05-04     75       96         78       64       90
#
#    Economics  History  Civis  Total
# 0         89       87     52    556
# 1         75       63     89    587
# ...

# %%
df["Total"].max()
# Out:
# 587

# %%
df["Total"].min()
# Out:
# 470

# %% [raw]
# Farha and Jennifer got the highest marks with 587 and John got the lowest with 470

# %%
df
# Out:
#        Name Gender        DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      Annu      F 1988-04-05     45       87         52       89       55
# 1     Farha      F 1990-08-12     55       63         89       75       78
# 2  Jennifer      F 1989-09-02     58       96         78       46       96
# 3   Jessica      F 1990-08-12     78       96         86       63       54
# 4      John      M 1988-04-05     55       45         56       87       21
# 5    Mukesh      M 1989-09-02     96       46         77       83       58
# 6     pooja      F 1987-05-04     55       64         61       58       75
# 7    Ramesh      M 1989-05-25     25       54         89       76       95
# 8    Ritesh      M 1989-05-25     54       76         87       56       25
# 9    Suresh      M 1987-05-04     75       96         78       64       90
#
#    Economics  History  Civis  Total
# 0         89       87     52    556
# 1         75       63     89    587
# ...

# %% [markdown]
# # Univariate Analysis

# %%
df_M=df.loc[df['Gender']=='M']
df_M
# Out:
#      Name Gender        DOB  Maths  Physics  Chemistry  English  Biology  \
# 4    John      M 1988-04-05     55       45         56       87       21
# 5  Mukesh      M 1989-09-02     96       46         77       83       58
# 7  Ramesh      M 1989-05-25     25       54         89       76       95
# 8  Ritesh      M 1989-05-25     54       76         87       56       25
# 9  Suresh      M 1987-05-04     75       96         78       64       90
#
#    Economics  History  Civis  Total
# 4         52       89     65    470
# 5         83       46     77    566
# 7         87       56     74    556
# 8         56       76     87    517
# 9         61       58      2    524

# %%
df_F=df.loc[df['Gender']=='F']
df_F
# Out:
#        Name Gender        DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      Annu      F 1988-04-05     45       87         52       89       55
# 1     Farha      F 1990-08-12     55       63         89       75       78
# 2  Jennifer      F 1989-09-02     58       96         78       46       96
# 3   Jessica      F 1990-08-12     78       96         86       63       54
# 6     pooja      F 1987-05-04     55       64         61       58       75
#
#    Economics  History  Civis  Total
# 0         89       87     52    556
# 1         75       63     89    587
# 2         77       83     53    587
# 3         89       75     45    586
# 6         58       64     61    496

# %%
plt.plot(df_M['Total'],np.zeros_like(df_M['Total']),'o')
plt.plot(df_F['Total'],np.zeros_like(df_F['Total']),'o')
plt.xlabel("Total Marks Obtained")
plt.show()

# %%
df.hist(figsize = (20,12), layout=(6, 3), bins = 'auto')
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'DOB', 'Maths', 'Physics', 'Chemistry', 'English',
#        'Biology', 'Economics', 'History', 'Civis', 'Total'],
#       dtype='object')

# %%
for i in ['Maths', 'Physics', 'Chemistry', 'English',
       'Biology', 'Economics', 'History', 'Civis', 'Total']:
    plt.boxplot(df[i])
    plt.show()

# %% [raw]
# There are outliers in Maths and Civics

# %%
for i in ['Maths', 'Physics', 'Chemistry', 'English',
       'Biology', 'Economics', 'History', 'Civis', 'Total']:
    sns.violinplot(x=i,data=df)
    plt.tight_layout()
    plt.show()

# %%
for i in ['Maths', 'Physics', 'Chemistry', 'English',
       'Biology', 'Economics', 'History', 'Civis', 'Total']:
    sns.distplot(df[i],bins='auto')
    plt.tight_layout()
    plt.show()

# %% [raw]
# We can infer from the above plots
# Maths,Physics,English,History: Normally distributed data
# Total,Chemistry,Civis,Biology: Right skewed distribution

# %% [markdown]
# # Bivariate Analysis

# %%
sns.FacetGrid(df,hue="Gender",size=5).map(plt.scatter,'Maths','Total').add_legend();
plt.show()

# %%
sns.catplot(x='Maths',y='Total',hue='Gender',data=df,kind='bar')

# %%
sns.catplot(x='Physics',y='Total',hue='Gender',data=df,kind='bar')

# %%
sns.catplot(x='Chemistry',y='Total',hue='Gender',data=df,kind='bar')

# %%
sns.catplot(x='Biology',y='Total',hue='Gender',data=df,kind='bar')

# %%
sns.catplot(x='English',y='Total',hue='Gender',data=df,kind='bar')

# %%
sns.catplot(x='Economics',y='Total',hue='Gender',data=df,kind='bar')

# %%
sns.catplot(x='History',y='Total',hue='Gender',data=df,kind='bar')

# %%
sns.catplot(x='Civis',y='Total',hue='Gender',data=df,kind='bar')

# %%
sns.catplot(x='Total',y='Total',hue='Gender',data=df,kind='bar')

# %% [raw]
# Male students obtained highest marks in 4 subjects namely: Maths, Physics, Chemistry aand History
# Female students obtained higher marks in other 4 subjects: English,Economics, Civis and Biology
# Getting the highest marks in any particular paper does not guarantee highest Total marks
# Most male scored better in Civis while most female score better in History
# Female students obtained higher total marks than male students

# %%
for i in df.columns:
    sns.barplot(df[i],df['Total'])
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Correlation

# %%
dfcorr=df.corr()
dfcorr
# Out:
#               Maths   Physics  Chemistry   English   Biology  Economics  \
# Maths      1.000000  0.113354   0.076751 -0.064074 -0.146598   0.000312
# Physics    0.113354  1.000000   0.117192 -0.562608  0.279638   0.191851
# Chemistry  0.076751  0.117192   1.000000 -0.409680  0.318032   0.235390
# English   -0.064074 -0.562608  -0.409680  1.000000 -0.330844   0.237577
# Biology   -0.146598  0.279638   0.318032 -0.330844  1.000000   0.370531
# Economics  0.000312  0.191851   0.235390  0.237577  0.370531   1.000000
# History   -0.320846  0.334082  -0.482710 -0.038775 -0.456131  -0.164953
# Civis     -0.274629 -0.643266   0.210908  0.186705 -0.330060   0.043905
# Total      0.156049  0.372033   0.545944 -0.132607  0.489008   0.830433
#
#             History     Civis     Total
# Maths     -0.320846 -0.274629  0.156049
# Physics    0.334082 -0.643266  0.372033
# Chemistry -0.482710  0.210908  0.545944
# English   -0.038775  0.186705 -0.132607
# Biology   -0.456131 -0.330060  0.489008
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dfcorr,cmap="Blues",annot=True)

# %% [raw]
# Dark shades have higher correlation
#
# There is high positive correlation between total marks and marks obtained in Economics,and somewhat for Chemistry and Biology
#
# There is somewhat high negative correlation between marks obtained in Civis & Physics, and,English & Physics

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df,hue="Gender",size=5)

# %%
df=pd.read_sql_query("select * from studmarks",engine)
df
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      Annu      F  1988-04-05     45       87         52       89       55
# 1     Farha      F  1990-08-12     55       63         89       75       78
# 2  Jennifer      F  1989-09-02     58       96         78       46       96
# 3   Jessica      F  1990-08-12     78       96         86       63       54
# 4      John      M  1988-04-05     55       45         56       87       21
# 5    Mukesh      M  1989-09-02     96       46         77       83       58
# 6     pooja      F  1987-05-04     55       64         61       58       75
# 7    Ramesh      M  1989-05-25     25       54         89       76       95
# 8    Ritesh      M  1989-05-25     54       76         87       56       25
# 9    Suresh      M  1987-05-04     75       96         78       64       90
#
#    Economics  History  Civis
# 0         89       87     52
# 1         75       63     89
# 2         77       83     53
# ...

# %%
print(pd.read_sql_query("select Maths,Name from studmarks order by Maths desc",engine))
#Mukesh got highest in Maths
# Out:
#    Maths      Name
# 0     96    Mukesh
# 1     78   Jessica
# 2     75    Suresh
# 3     58  Jennifer
# 4     55     Farha
# 5     55      John
# 6     55     pooja
# 7     54    Ritesh
# 8     45      Annu
# 9     25    Ramesh

# %%
print(pd.read_sql_query("select Physics,Name from studmarks order by Physics desc",engine))
#Jennifer,Jessica,Suresh got highest in Physics
# Out:
#    Physics      Name
# 0       96  Jennifer
# 1       96   Jessica
# 2       96    Suresh
# 3       87      Annu
# 4       76    Ritesh
# 5       64     pooja
# 6       63     Farha
# 7       54    Ramesh
# 8       46    Mukesh
# 9       45      John

# %%
print(pd.read_sql_query("select Chemistry,Name from studmarks order by Chemistry desc",engine))
#Farha,Ramesh got highest in Chemistry
# Out:
#    Chemistry      Name
# 0         89     Farha
# 1         89    Ramesh
# 2         87    Ritesh
# 3         86   Jessica
# 4         78  Jennifer
# 5         78    Suresh
# 6         77    Mukesh
# 7         61     pooja
# 8         56      John
# 9         52      Annu

# %%
print(pd.read_sql_query("select Biology,Name from studmarks order by Biology desc",engine))
#Jennifer got highest in Biology
# Out:
#    Biology      Name
# 0       96  Jennifer
# 1       95    Ramesh
# 2       90    Suresh
# 3       78     Farha
# 4       75     pooja
# 5       58    Mukesh
# 6       55      Annu
# 7       54   Jessica
# 8       25    Ritesh
# 9       21      John

# %%
print(pd.read_sql_query("select English,Name from studmarks order by English desc",engine))
#Annu got highest in English
# Out:
#    English      Name
# 0       89      Annu
# 1       87      John
# 2       83    Mukesh
# 3       76    Ramesh
# 4       75     Farha
# 5       64    Suresh
# 6       63   Jessica
# 7       58     pooja
# 8       56    Ritesh
# 9       46  Jennifer

# %%
print(pd.read_sql_query("select Economics,Name from studmarks order by Economics desc",engine))
#Annu, Jessica got highest in Economics
# Out:
#    Economics      Name
# 0         89      Annu
# 1         89   Jessica
# 2         87    Ramesh
# 3         83    Mukesh
# 4         77  Jennifer
# 5         75     Farha
# 6         61    Suresh
# 7         58     pooja
# 8         56    Ritesh
# 9         52      John

# %%
print(pd.read_sql_query("select History,Name from studmarks order by History desc",engine))
#John got highest in History
# Out:
#    History      Name
# 0       89      John
# 1       87      Annu
# 2       83  Jennifer
# 3       76    Ritesh
# 4       75   Jessica
# 5       64     pooja
# 6       63     Farha
# 7       58    Suresh
# 8       56    Ramesh
# 9       46    Mukesh

# %%
print(pd.read_sql_query("select Civis,Name from studmarks order by Civis desc",engine))
#Farha got highest in Civis
# Out:
#    Civis      Name
# 0     89     Farha
# 1     87    Ritesh
# 2     77    Mukesh
# 3     74    Ramesh
# 4     65      John
# 5     61     pooja
# 6     53  Jennifer
# 7     52      Annu
# 8     45   Jessica
# 9      2    Suresh

# %% [markdown]
# # Considering 50 is the pass mark

# %%
print(pd.read_sql_query("select Name from studmarks where Maths<50",engine))
#Ramesh,Annu failed in Maths
# Out:
#      Name
# 0    Annu
# 1  Ramesh

# %%
print(pd.read_sql_query("select Name from studmarks where Chemistry<50",engine))
#No one failed in Chemistry
# Out:
# Empty DataFrame
# Columns: [Name]
# Index: []

# %%
print(pd.read_sql_query("select Name from studmarks where Physics<50",engine))
#John,Mukesh failed in Physics
# Out:
#      Name
# 0    John
# 1  Mukesh

# %%
print(pd.read_sql_query("select Name from studmarks where Biology<50",engine))
#John,Ritesh failed in Physics
# Out:
#      Name
# 0    John
# 1  Ritesh

# %%
print(pd.read_sql_query("select Name from studmarks where English<50",engine))
#Jennifer failed in English
# Out:
#        Name
# 0  Jennifer

# %%
print(pd.read_sql_query("select Name from studmarks where Economics<50",engine))
#No one failed in Economics
# Out:
# Empty DataFrame
# Columns: [Name]
# Index: []

# %%
print(pd.read_sql_query("select Name from studmarks where History<50",engine))
#Mukesh failed in History
# Out:
#      Name
# 0  Mukesh

# %%
print(pd.read_sql_query("select Name from studmarks where Civis<50",engine))
#Jessica,Suresh failed in Civis
# Out:
#       Name
# 0  Jessica
# 1   Suresh

# %% [markdown]
# # Finding the average marks in different subjects

# %%
print(pd.read_sql_query("select avg(Maths),avg(Physics),avg(Chemistry),avg(Biology),avg(English),avg(Economics),avg(History),avg(Civis)  from studmarks ",engine))
# Out:
#    avg(Maths)  avg(Physics)  avg(Chemistry)  avg(Biology)  avg(English)  \
# 0        59.6          72.3            75.3          64.7          69.7
#
#    avg(Economics)  avg(History)  avg(Civis)
# 0            72.7          69.7        60.5

# %% [raw]
# We can see maximum avg score is for Chemistry  while Maths has the lowest average score

# %%
print(pd.read_sql_query("select Name from studmarks where Maths>59.6",engine))
#3 scored better than avg
# Out:
#       Name
# 0  Jessica
# 1   Mukesh
# 2   Suresh

# %%
print(pd.read_sql_query("select Name from studmarks where Physics>72.3",engine))
#5 scored better than avg
# Out:
#        Name
# 0      Annu
# 1  Jennifer
# 2   Jessica
# 3    Ritesh
# 4    Suresh

# %%
print(pd.read_sql_query("select Name from studmarks where Chemistry>75.3",engine))
#7 scored better than avg
# Out:
#        Name
# 0     Farha
# 1  Jennifer
# 2   Jessica
# 3    Mukesh
# 4    Ramesh
# 5    Ritesh
# 6    Suresh

# %%
print(pd.read_sql_query("select Name from studmarks where Biology>64.7",engine))
#5 scored better than avg
# Out:
#        Name
# 0     Farha
# 1  Jennifer
# 2     pooja
# 3    Ramesh
# 4    Suresh

# %%
print(pd.read_sql_query("select Name from studmarks where English>69.7",engine))
#5 scored better than avg
# Out:
#      Name
# 0    Annu
# 1   Farha
# 2    John
# 3  Mukesh
# 4  Ramesh

# %%
avg()  avg(History)  avg(Civis)  
0            72.7          69.7        60.5

# %%
print(pd.read_sql_query("select Name from studmarks where Economics>72.7",engine))
#6 scored better than avg
# Out:
#        Name
# 0      Annu
# 1     Farha
# 2  Jennifer
# 3   Jessica
# 4    Mukesh
# 5    Ramesh

# %%
print(pd.read_sql_query("select Name from studmarks where History>69.7",engine))
#5 scored better than avg
# Out:
#        Name
# 0      Annu
# 1  Jennifer
# 2   Jessica
# 3      John
# 4    Ritesh

# %%
print(pd.read_sql_query("select Name from studmarks where Civis>60.5",engine))
#6 scored better than avg
# Out:
#      Name
# 0   Farha
# 1    John
# 2  Mukesh
# 3   pooja
# 4  Ramesh
# 5  Ritesh
